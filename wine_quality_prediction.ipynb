# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/winequality.csv",sep=";")

# %%
data.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.0              0.27         0.36           20.70      0.045
# 1             6.3              0.30         0.34            1.60      0.049
# 2             8.1              0.28         0.40            6.90      0.050
# 3             7.2              0.23         0.32            8.50      0.058
# 4             7.2              0.23         0.32            8.50      0.058
# 5             8.1              0.28         0.40            6.90      0.050
# 6             6.2              0.32         0.16            7.00      0.045
# 7             7.0              0.27         0.36           20.70      0.045
# 8             6.3              0.30         0.34            1.60      0.049
# 9             8.1              0.22         0.43            1.50      0.044
# 10            8.1              0.27         0.41            1.45      0.033
# 11            8.6              0.23         0.40            4.20      0.035
# 12            7.9              0.18         0.37            1.20      0.040
# 13            6.6              0.16         0.40            1.50      0.044
# 14            8.3              0.42         0.62           19.25      0.040
# 15            6.6              0.17         0.38            1.50      0.032
# 16            6.3              0.48         0.04            1.10      0.046
# 17            6.2              0.66         0.48            1.20      0.029
# 18            7.4              0.34         0.42            1.10      0.033
# 19            6.5              0.31         0.14            7.50      0.044
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  45.0                 170.0   1.0010  3.00       0.45
# 1                  14.0                 132.0   0.9940  3.30       0.49
# 2                  30.0                  97.0   0.9951  3.26       0.44
# 3                  47.0                 186.0   0.9956  3.19       0.40
# 4                  47.0                 186.0   0.9956  3.19       0.40
# 5                  30.0                  97.0   0.9951  3.26       0.44
# 6                  30.0                 136.0   0.9949  3.18       0.47
# 7                  45.0                 170.0   1.0010  3.00       0.45
# 8                  14.0                 132.0   0.9940  3.30       0.49
# 9                  28.0                 129.0   0.9938  3.22       0.45
# 10                 11.0                  63.0   0.9908  2.99       0.56
# 11                 17.0                 109.0   0.9947  3.14       0.53
# 12                 16.0                  75.0   0.9920  3.18       0.63
# 13                 48.0                 143.0   0.9912  3.54       0.52
# 14                 41.0                 172.0   1.0002  2.98       0.67
# 15                 28.0                 112.0   0.9914  3.25       0.55
# 16                 30.0                  99.0   0.9928  3.24       0.36
# 17                 29.0                  75.0   0.9892  3.33       0.39
# 18                 17.0                 171.0   0.9917  3.12       0.53
# 19                 34.0                 133.0   0.9955  3.22       0.50
#
#     alcohol  quality
# 0       8.8        6
# 1       9.5        6
# 2      10.1        6
# 3       9.9        6
# 4       9.9        6
# 5      10.1        6
# 6       9.6        6
# 7       8.8        6
# 8       9.5        6
# 9      11.0        6
# 10     12.0        5
# 11      9.7        5
# 12     10.8        5
# 13     12.4        7
# 14      9.7        5
# 15     11.4        7
# 16      9.6        6
# 17     12.8        8
# 18     11.3        6
# 19      9.5        5

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
new_df=data[data['quality'].isin([5,6,7])]
new_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4535 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4535 non-null   float64
#  1   volatile acidity      4535 non-null   float64
#  2   citric acid           4535 non-null   float64
#  3   residual sugar        4535 non-null   float64
#  4   chlorides             4535 non-null   float64
#  5   free sulfur dioxide   4535 non-null   float64
#  6   total sulfur dioxide  4535 non-null   float64
#  7   density               4535 non-null   float64
#  8   pH                    4535 non-null   float64
#  9   sulphates             4535 non-null   float64
#  10  alcohol               4535 non-null   float64
#  11  quality               4535 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 460.6 KB

# %%
new_df['quality'].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# Name: count, dtype: int64

# %%
X = new_df.drop("quality", axis=1)

y = new_df["quality"]

# %%
new_df.groupby("quality").count()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 5                 1457              1457         1457            1457
# 6                 2198              2198         2198            2198
# 7                  880               880          880             880
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# 5             1457                 1457                  1457     1457  1457
# 6             2198                 2198                  2198     2198  2198
# 7              880                  880                   880      880   880
#
#          sulphates  alcohol
# quality
# 5             1457     1457
# 6             2198     2198
# 7              880      880

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(

    X, y, test_size=0.2, random_state=0

)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.naive_bayes import GaussianNB
classifier=GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
X_train
# Out:
# array([[ 0.54460045,  1.63662349,  0.28925438, ...,  0.2756489 ,
#         -0.54254348,  2.25337036],
#        [ 0.54460045, -0.15526017, -0.12655309, ..., -0.78323983,
#         -0.36510296,  1.26295822],
#        [-0.54310141,  0.89878904, -1.124491  , ...,  0.34182945,
#         -0.54254348, -0.80040039],
#        ...,
#        [-1.02652446, -0.15526017, -0.37603757, ...,  1.26835709,
#         -0.45382322,  1.51056126],
#        [-1.26823599, -0.57687986, -0.37603757, ..., -0.31997601,
#         -1.16358533,  0.52014912],
#        [-0.18053412,  0.89878904, -0.62552205, ..., -1.31268419,
#         -1.69590691,  1.42802691]])

# %%
X_test
# Out:
# array([[ 0.0611774 , -0.89309462,  0.45557736, ..., -0.51851764,
#          1.49802257,  0.27254609],
#        [-0.9056687 , -0.68228478, -0.29287607, ...,  0.54037109,
#         -1.60718665,  1.84069864],
#        [-0.42224565, -1.20930938, -0.04339159, ...,  0.73891273,
#         -0.89742454,  0.76775216],
#        ...,
#        [-1.8725148 ,  1.26770627, -2.20559041, ...,  2.06252364,
#         -1.25230559,  0.1074774 ],
#        [-0.66395718, -0.04985525, -1.29081399, ...,  0.2756489 ,
#         -0.18766243, -1.21307211],
#        [ 0.42374469,  1.32040873,  1.28719229, ..., -1.1803231 ,
#         -0.63126375, -0.96546908]])

# %%
ypred=classifier.predict(X_test)

# %%
ypred
# Out:
# array([7, 7, 7, 5, 7, 7, 6, 7, 5, 5, 7, 5, 5, 7, 6, 5, 5, 7, 7, 7, 6, 5,
#        5, 7, 6, 7, 7, 7, 7, 7, 7, 6, 7, 6, 7, 6, 5, 7, 7, 7, 5, 6, 7, 7,
#        7, 7, 6, 5, 6, 5, 5, 6, 7, 5, 7, 6, 7, 7, 6, 7, 5, 6, 6, 6, 5, 5,
#        5, 7, 5, 6, 7, 7, 6, 6, 6, 5, 7, 7, 7, 5, 7, 6, 7, 6, 5, 6, 5, 6,
#        6, 6, 5, 7, 6, 5, 5, 7, 7, 5, 6, 5, 5, 6, 5, 5, 5, 5, 5, 7, 6, 5,
#        7, 5, 6, 5, 6, 5, 6, 5, 6, 7, 5, 7, 7, 7, 7, 7, 5, 5, 7, 6, 7, 5,
#        6, 5, 6, 5, 7, 5, 5, 7, 7, 7, 7, 6, 5, 5, 6, 5, 6, 5, 7, 5, 5, 7,
#        7, 6, 6, 6, 5, 5, 6, 6, 6, 7, 6, 7, 7, 5, 6, 6, 6, 7, 5, 6, 6, 6,
#        7, 7, 7, 5, 7, 6, 5, 6, 5, 6, 6, 7, 5, 6, 6, 7, 7, 6, 7, 7, 7, 7,
#        5, 7, 6, 5, 7, 7, 6, 5, 5, 6, 6, 7, 7, 6, 6, 5, 6, 6, 5, 5, 6, 5,
#        5, 5, 7, 6, 7, 5, 6, 7, 7, 5, 5, 5, 7, 6, 5, 5, 5, 7, 6, 5, 5, 5,
#        6, 6, 5, 6, 6, 7, 6, 6, 6, 6, 6, 6, 7, 6, 5, 7, 5, 7, 7, 6, 5, 5,
#        7, 5, 5, 7, 7, 7, 7, 5, 7, 7, 7, 6, 7, 6, 6, 6, 7, 5, 6, 7, 5, 7,
#        5, 7, 7, 6, 6, 5, 7, 5, 7, 7, 7, 5, 5, 7, 5, 6, 6, 7, 7, 5, 6, 6,
#        5, 7, 7, 7, 5, 5, 7, 6, 5, 5, 7, 7, 6, 6, 6, 7, 7, 5, 7, 6, 6, 6,
#        7, 5, 5, 6, 6, 5, 5, 7, 7, 6, 5, 5, 7, 6, 5, 7, 7, 5, 7, 7, 5, 6,
#        7, 7, 5, 6, 7, 5, 6, 5, 7, 5, 5, 7, 5, 7, 5, 6, 6, 5, 5, 5, 7, 5,
#        6, 6, 6, 5, 6, 6, 5, 6, 5, 5, 5, 5, 7, 6, 5, 7, 6, 6, 5, 7, 6, 7,
#        6, 5, 6, 6, 6, 6, 5, 7, 5, 5, 6, 5, 7, 5, 7, 7, 7, 7, 7, 6, 6, 5,
#        6, 5, 6, 5, 7, 6, 7, 5, 7, 7, 5, 7, 7, 6, 7, 6, 7, 6, 5, 7, 7, 5,
#        5, 6, 5, 5, 5, 7, 7, 5, 7, 6, 6, 7, 6, 5, 5, 5, 5, 6, 6, 7, 6, 6,
#        5, 5, 6, 6, 5, 6, 7, 7, 7, 5, 7, 7, 5, 5, 6, 6, 6, 7, 7, 7, 7, 6,
#        5, 7, 7, 5, 5, 5, 5, 6, 7, 7, 6, 6, 7, 6, 7, 5, 5, 6, 6, 5, 7, 6,
#        7, 6, 6, 7, 7, 7, 6, 7, 5, 5, 6, 6, 6, 5, 7, 7, 7, 5, 7, 6, 7, 5,
#        5, 7, 7, 5, 6, 5, 5, 6, 5, 6, 5, 7, 5, 5, 6, 7, 6, 7, 6, 7, 5, 6,
#        6, 5, 6, 5, 5, 6, 5, 7, 7, 6, 6, 5, 5, 6, 6, 7, 7, 6, 5, 6, 7, 6,
#        5, 6, 5, 7, 7, 7, 5, 6, 6, 6, 5, 5, 5, 5, 5, 7, 6, 5, 7, 7, 6, 6,
#        6, 5, 6, 5, 7, 6, 5, 5, 5, 5, 7, 5, 5, 7, 7, 7, 5, 5, 5, 6, 6, 7,
#        7, 6, 5, 7, 7, 7, 6, 7, 7, 5, 6, 7, 6, 7, 7, 5, 6, 7, 5, 5, 6, 7,
#        6, 5, 7, 6, 7, 6, 6, 7, 6, 7, 6, 7, 6, 7, 7, 6, 5, 7, 6, 6, 7, 6,
#        6, 7, 7, 5, 7, 7, 7, 5, 5, 6, 6, 5, 5, 7, 6, 7, 5, 5, 5, 6, 5, 7,
#        6, 5, 7, 6, 5, 7, 5, 7, 7, 5, 5, 6, 7, 7, 7, 5, 7, 5, 5, 5, 7, 5,
#        7, 5, 6, 6, 6, 7, 5, 7, 7, 7, 5, 6, 5, 6, 5, 6, 5, 7, 5, 6, 5, 5,
#        6, 7, 5, 7, 5, 7, 7, 6, 5, 6, 5, 7, 7, 6, 6, 7, 6, 7, 6, 5, 7, 5,
#        7, 7, 6, 7, 6, 6, 7, 7, 5, 6, 5, 5, 6, 5, 6, 7, 6, 5, 6, 6, 7, 5,
#        7, 5, 7, 6, 5, 6, 6, 6, 7, 7, 5, 7, 5, 6, 7, 5, 6, 7, 7, 5, 7, 6,
#        5, 6, 5, 6, 6, 6, 5, 7, 5, 6, 6, 7, 5, 5, 7, 5, 6, 6, 5, 7, 7, 5,
#        7, 5, 6, 7, 7, 7, 7, 5, 7, 5, 5, 6, 7, 6, 5, 6, 7, 5, 7, 5, 7, 6,
#        7, 5, 7, 6, 5, 5, 5, 5, 6, 7, 7, 7, 5, 6, 7, 7, 7, 7, 5, 6, 6, 6,
#        7, 5, 6, 7, 7, 5, 7, 6, 6, 7, 6, 6, 6, 5, 5, 7, 5, 7, 5, 6, 6, 6,
#        7, 6, 5, 7, 6, 6, 5, 5, 6, 5, 7, 7, 5, 5, 5, 7, 6, 7, 7, 5, 6, 7,
#        7, 6, 6, 5, 5])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,ypred)
print(cm)
# Out:
# [[171 100  31]
#  [117 150 162]
#  [ 14  35 127]]

# %%
accuracy_score(y_test,ypred)
# Out:
# 0.49393605292171994

# %%
ypred.shape
# Out:
# (907,)

# %%
Results=pd.DataFrame(columns=['Actual','Predicted'])
Results['Actual']=y_test
Results['Predicted']=ypred
Results.head(25)
# Out:
#       Actual  Predicted
# 2015       6          7
# 3858       6          7
# 4599       7          7
# 410        6          5
# 2624       5          7
# 2118       6          7
# 78         5          6
# 2281       6          7
# 2546       5          5
# 1507       6          5
# 2558       7          7
# 1304       5          5
# 842        7          5
# 942        7          7
# 3804       5          6
# 535        5          5
# 489        6          5
# 3183       6          7
# 4049       6          7
# 1226       7          7
# 568        6          6
# 233        6          5
# 960        6          5
# 2214       5          7
# 170        6          6
